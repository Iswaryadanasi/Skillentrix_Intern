# %% [markdown]
# <a href="https://colab.research.google.com/github/Iswaryadanasi/Skillentrix_Intern/blob/main/House_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("House Price Prediction Project Started")
# Out:
# House Price Prediction Project Started

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

data = {
    'Area': [1000, 1200, 1500, 1800, 2000],
    'Price': [200000, 250000, 300000, 350000, 400000]
}

df = pd.DataFrame(data)

X = df[['Area']]
y = df['Price']

model = LinearRegression()
model.fit(X, y)

new_data = pd.DataFrame({'Area': [1600]})
predicted_price = model.predict(new_data)

print("Predicted price for 1600 sq ft house:")
print(predicted_price[0])
# Out:
# Predicted price for 1600 sq ft house:
# 319117.64705882355
